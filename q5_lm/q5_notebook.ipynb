# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcavusoglu/takeHomeMidterm/blob/main/q5_lm/q5_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/ugurcavusoglu/takeHomeMidterm.git
# Out:
# /content
# fatal: destination path 'takeHomeMidterm' already exists and is not an empty directory.

# %%
# %cd /content/takeHomeMidterm
# !pip install -r requirements.txt -q
# Out:
# /content/takeHomeMidterm

# %%
# %cd /content/takeHomeMidterm/q5_lm
# !python evaluate.py
# Out:
# /content/takeHomeMidterm/q5_lm
# Device: cuda
# Train tokens: 2,051,910 | Val tokens: 213,886 | Test tokens: 241,211
#
# Building 3-gram LM...
# N-gram Test Perplexity: 32372.30
# Vocab size: 39275 | Train batches: 501 | Val batches: 53
#
# Training LSTM LM...
# Epoch  1 | Train Loss: 7.3044 | Val Loss: 6.6500 | Val PPL: 772.80
# Epoch  2 | Train Loss: 6.7381 | Val Loss: 6.1561 | Val PPL: 471.61
# Epoch  3 | Train Loss: 6.3064 | Val Loss: 5.9077 | Val PPL: 367.88
# Epoch  4 | Train Loss: 6.0831 | Val Loss: 5.7697 | Val PPL: 320.45
# Epoch  5 | Train Loss: 5.9269 | Val Loss: 5.6706 | Val PPL: 290.21
# Epoch  6 | Train Loss: 5.7942 | Val Loss: 5.5906 | Val PPL: 267.90
# Epoch  7 | Train Loss: 5.6705 | Val Loss: 5.5187 | Val PPL: 249.31
# Epoch  8 | Train Loss: 5.5599 | Val Loss: 5.4568 | Val PPL: 234.35
# Epoch  9 | Train Loss: 5.4669 | Val Loss: 5.4163 | Val PPL: 225.05
# Epoch 10 | Train Loss: 5.3854 | Val Loss: 5.3839 | Val PPL: 217.87
# ...
