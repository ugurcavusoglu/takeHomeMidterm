# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcavusoglu/takeHomeMidterm/blob/main/q2_ner/q2_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ugurcavusoglu/takeHomeMidterm.git
# Out:
# fatal: destination path 'takeHomeMidterm' already exists and is not an empty directory.

# %%
# %cd /content/takeHomeMidterm
# !pip install -r requirements.txt
# Out:
# /content/takeHomeMidterm
# ...

# %%
# %cd /content/takeHomeMidterm
# !wget --no-check-certificate "https://huggingface.co/stanfordnlp/glove/resolve/main/glove.6B.zip" -O glove.6B.zip
# !unzip -q glove.6B.zip glove.6B.100d.txt
# !cp glove.6B.100d.txt q2_ner/
# Out:
# /content/takeHomeMidterm
# --2026-05-02 13:37:46--  https://huggingface.co/stanfordnlp/glove/resolve/main/glove.6B.zip
# Resolving huggingface.co (huggingface.co)... 18.164.174.55, 18.164.174.17, 18.164.174.23, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.55|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content/takeHomeMidterm/q2_ner
# !python train_bilstm_crf.py
# Out:
# /content/takeHomeMidterm/q2_ner
# Traceback (most recent call last):
#   File "/content/takeHomeMidterm/q2_ner/train_bilstm_crf.py", line 6, in <module>
#     from torchcrf import CRF
# ModuleNotFoundError: No module named 'torchcrf'

# %%
# %cd /content/takeHomeMidterm
# !git pull
# !pip install pytorch-crf
# %cd q2_ner
# !python train_bilstm_crf.py
# Out:
# /content/takeHomeMidterm
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 469 bytes | 156.00 KiB/s, done.
# From https://github.com/ugurcavusoglu/takeHomeMidterm
#    5cb1674..de38711  main       -> origin/main
# Updating 5cb1674..de38711
# Fast-forward
#  q2_ner/train_bilstm_crf.py | 2 +-
#  requirements.txt           | 2 +-
#  2 files changed, 2 insertions(+), 2 deletions(-)
# ...
# /content/takeHomeMidterm/q2_ner
# Device: cuda
# === BiLSTM-CRF NER ===
#
# ...
# Generating train split: 100% 14041/14041 [00:01<00:00, 9005.89 examples/s]
# Generating validation split: 100% 3250/3250 [00:00<00:00, 8472.77 examples/s]
# Generating test split: 100% 3453/3453 [00:00<00:00, 9245.28 examples/s]
# Train: 14041 | Val: 3250 | Test: 3453 sentences
# GloVe: 18415/21011 tokens found
# ...

# %%
# %cd /content/takeHomeMidterm/q2_ner
# !python train_bert_ner.py
# Out:
# /content/takeHomeMidterm/q2_ner
# 2026-05-02 13:56:51.010542: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === BERT NER (bert-base-cased) ===
#
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 314kB/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 570/570 [00:00<00:00, 5.16MB/s]
# vocab.txt: 213kB [00:00, 2.56MB/s]
# tokenizer.json: 436kB [00:00, 3.08MB/s]
# Map: 100% 14041/14041 [00:02<00:00, 5318.16 examples/s]
# Map: 100% 3250/3250 [00:00<00:00, 8153.12 examples/s]
# ...
