# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcavusoglu/takeHomeMidterm/blob/main/q1_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ugurcavusoglu/takeHomeMidterm.git
# %cd takeHomeMidterm
# Out:
# fatal: destination path 'takeHomeMidterm' already exists and is not an empty directory.
# /content/takeHomeMidterm

# %%
# !pip install -r requirements.txt

# %%
# !wget --no-check-certificate "https://huggingface.co/stanfordnlp/glove/resolve/main/glove.6B.zip" -O glove.6B.zip
# !unzip -q glove.6B.zip glove.6B.100d.txt
# !mv glove.6B.100d.txt q1_classification/
# Out:
# --2026-05-02 10:21:40--  https://huggingface.co/stanfordnlp/glove/resolve/main/glove.6B.zip
# Resolving huggingface.co (huggingface.co)... 3.167.192.19, 3.167.192.6, 3.167.192.4, ...
# Connecting to huggingface.co (huggingface.co)|3.167.192.19|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !unzip -q glove.6B.zip glove.6B.100d.txt
# !mv glove.6B.100d.txt /content/takeHomeMidterm/q1_classification/
# Out:
# replace glove.6B.100d.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# mv: 'glove.6B.100d.txt' and '/content/takeHomeMidterm/q1_classification/glove.6B.100d.txt' are the same file

# %%
# %cd /content/takeHomeMidterm/q1_classification
# !python train_tfidf.py
# Out:
# /content/takeHomeMidterm/q1_classification
# === TF-IDF + Logistic Regression ===
#
# Train: 22500 | Val: 2500 | Test: 25000
# Training time: 24.8s
#
# Validation:
#   Accuracy : 0.9064
#   Macro-F1 : 0.9064
#               precision    recall  f1-score   support
#
#     Negative       0.90      0.91      0.91      1243
#     Positive       0.91      0.90      0.91      1257
#
#     accuracy                           0.91      2500
#    macro avg       0.91      0.91      0.91      2500
# weighted avg       0.91      0.91      0.91      2500
#
#
# Test:
#   Accuracy : 0.8985
#   Macro-F1 : 0.8985
#               precision    recall  f1-score   support
#
#     Negative       0.90      0.89      0.90     12500
#     Positive       0.90      0.90      0.90     12500
#
#     accuracy                           0.90     25000
#    macro avg       0.90      0.90      0.90     25000
# weighted avg       0.90      0.90      0.90     25000
#
#
# ...

# %%
# !python train_bilstm.py
# Out:
# Device: cuda
# === BiLSTM + GloVe ===
#
# Train: 22500 | Val: 2500 | Test: 25000
# GloVe: 29397/30000 tokens found
# Epoch 1/5 | Train Loss: 0.6119 | Val Loss: 0.4735
# Epoch 2/5 | Train Loss: 0.3779 | Val Loss: 0.2993
# Epoch 3/5 | Train Loss: 0.2417 | Val Loss: 0.2831
# Epoch 4/5 | Train Loss: 0.1657 | Val Loss: 0.2791
# Epoch 5/5 | Train Loss: 0.1146 | Val Loss: 0.3284
#
# Validation:
#   Accuracy : 0.8852
#   Macro-F1 : 0.8852
#               precision    recall  f1-score   support
#
#     Negative       0.87      0.90      0.89      1243
#     Positive       0.90      0.87      0.88      1257
#
#     accuracy                           0.89      2500
#    macro avg       0.89      0.89      0.89      2500
# weighted avg       0.89      0.89      0.89      2500
#
#
# Test:
#   Accuracy : 0.8528
#   Macro-F1 : 0.8526
#               precision    recall  f1-score   support
#
#     Negative       0.83      0.89      0.86     12500
# ...

# %%
# !pip install -q "transformers==4.41.0" "accelerate==0.30.0" "peft==0.11.1"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 9.2 MB/s eta 0:00:00

# %%
# %cd /content/takeHomeMidterm/q1_classification
# !python train_bert.py
# Out:
# /content/takeHomeMidterm/q1_classification
# 2026-05-02 10:29:49.832737: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/takeHomeMidterm/q1_classification/train_bert.py", line 24, in <module>
#     accuracy_metric = hf_evaluate.load("accuracy")
#                       ^^^^^^^^^^^^^^^^
# AttributeError: module 'evaluate' has no attribute 'load'

# %%
# !pip install -q evaluate scikit-learn
import importlib
import evaluate
importlib.reload(evaluate)
print(evaluate.__version__)
# Out:
# 0.4.2

# %%
import os
os.remove("/content/takeHomeMidterm/q1_classification/evaluate.py")
# !python q1_classification/train_bert.py
# Out:
# ...
# === DistilBERT Fine-tuning ===
#
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 184kB/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 483/483 [00:00<00:00, 4.35MB/s]
# vocab.txt: 232kB [00:00, 3.22MB/s]
# tokenizer.json: 466kB [00:00, 3.68MB/s]
# Map: 100% 22500/22500 [00:21<00:00, 1062.93 examples/s]
# Map: 100% 2500/2500 [00:01<00:00, 1253.31 examples/s]
# Map: 100% 25000/25000 [00:20<00:00, 1193.29 examples/s]
# model.safetensors: 100% 268M/268M [00:02<00:00, 127MB/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# ...
