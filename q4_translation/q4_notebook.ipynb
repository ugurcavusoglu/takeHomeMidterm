# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcavusoglu/takeHomeMidterm/blob/main/q4_translation/q4_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/ugurcavusoglu/takeHomeMidterm.git
# Out:
# /content
# fatal: destination path 'takeHomeMidterm' already exists and is not an empty directory.

# %%
# %cd /content/takeHomeMidterm
# !pip install -r requirements.txt -q
# Out:
# /content/takeHomeMidterm

# %%
# %cd q4_translation
# !python evaluate.py
# Out:
# /content/takeHomeMidterm/q4_translation
# 2026-05-06 09:41:09.923353: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Device: cuda
# ...
# Generating train split: 100% 29000/29000 [00:00<00:00, 477989.00 examples/s]
# Generating validation split: 100% 1014/1014 [00:00<00:00, 440590.93 examples/s]
# Generating test split: 100% 1000/1000 [00:00<00:00, 502011.25 examples/s]
# Train: 29000 | Val: 1014 | Test: 1000
# Src vocab size: 7704 | Tgt vocab size: 9597
#
# Training Seq2Seq...
# Epoch  1 | Train Loss: 4.2039 | Val Loss: 3.5436
# Epoch  2 | Train Loss: 3.0060 | Val Loss: 3.3919
# Epoch  3 | Train Loss: 2.4897 | Val Loss: 3.3378
# Epoch  4 | Train Loss: 2.1426 | Val Loss: 3.3096
# Epoch  5 | Train Loss: 1.9509 | Val Loss: 3.3397
# ...
