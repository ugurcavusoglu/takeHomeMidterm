# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcavusoglu/takeHomeMidterm/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !rm -rf takeHomeMidterm
# !git clone https://github.com/ugurcavusoglu/takeHomeMidterm.git
# %cd /content/takeHomeMidterm
# !pip install -r requirements.txt -q
# %cd q3_summarization
# !python evaluate.py
# Out:
# /content
# Cloning into 'takeHomeMidterm'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 71 (delta 31), reused 50 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (71/71), 179.83 KiB | 29.97 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# /content/takeHomeMidterm
# /content/takeHomeMidterm/q3_summarization
# Loaded 1000 samples from CNN/DailyMail test split
# Avg article length : 676 words
# Avg summary length : 55 words
#
# Running TextRank...
# TextRank: 100% 1000/1000 [00:06<00:00, 151.19it/s]
#
# Running BART...
# Device: cuda
# BART inference: 100% 125/125 [17:48<00:00,  8.54s/it]
#
# === TextRank (Extractive) ===
# WARNING:sacrebleu:That's 100 lines that end in a tokenized period ('.')
# WARNING:sacrebleu:It looks like you forgot to detokenize your test data, which may hurt your score.
# ...

# %%
# !git -C /content/takeHomeMidterm pull origin main
# %cd /content/takeHomeMidterm/q3_summarization
# !python evaluate.py
# Out:
# From https://github.com/ugurcavusoglu/takeHomeMidterm
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# /content/takeHomeMidterm/q3_summarization
# Loaded 1000 samples from CNN/DailyMail test split
# Avg article length : 676 words
# Avg summary length : 55 words
#
# Running TextRank...
# TextRank: 100% 1000/1000 [00:05<00:00, 185.51it/s]
#
# Loading cached BART summaries...
#
# === TextRank (Extractive) ===
# WARNING:sacrebleu:That's 100 lines that end in a tokenized period ('.')
# WARNING:sacrebleu:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:sacrebleu:If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 168kB/s]
# ...
